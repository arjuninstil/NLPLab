# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("private/sorted_train.csv")
df.head()
# Out:
#                                                 text company  year  \
# 0      Risks arising from external factors  inclu...  3i grp  2009
# 1    managing the business.  \x96 Meets monthly. ...  3i grp  2015
# 2    framework   Annual and half-year reports   Q...  3i grp  2014
# 3    the Group\x92s   regulatory compliance funct...  3i grp  2013
# 4    risks under active  review by the Group Risk...  3i grp  2013
#
#           file_name  dummy1  dummy2  dummy3
# 0   3I GRP_2009.TXT       1       0       0
# 1   3I GRP_2015.TXT       1       0       0
# 2   3I GRP_2014.TXT       1       0       0
# 3   3I GRP_2013.TXT       1       1       1
# 4   3I GRP_2013.TXT       1       0       0

# %%
df[df['company']=='bnp paribas']
# Out:
#                                                    text      company  year  \
# 3699    fi nancial assets, including those reclassif...  bnp paribas  2012
# 3700    drawn up a pragmatic, broader legal outsourc...  bnp paribas  2012
# 3701    permanent  member. In addition, the Legal f ...  bnp paribas  2012
# 3702    of staff at  various levels of the organisat...  bnp paribas  2012
# 3703   , earthquakes and terrorist attacks. Credit o...  bnp paribas  2012
# 3704    eligible for Tier 2 capital  888 888 Derivat...  bnp paribas  2012
# 3705    loans to credit or fi nancial  institutions ...  bnp paribas  2012
# 3706    reclassifi ed as loans and receivables  (365...  bnp paribas  2012
# 3707    assets, including those reclassifi ed as loa...  bnp paribas  2012
# 3708     tax regulations applicable to companies eng...  bnp paribas  2012
# 3709     31 December 2012  31 December 2011   Availa...  bnp paribas  2012
# ...
